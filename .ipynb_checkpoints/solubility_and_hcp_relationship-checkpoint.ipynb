# %% [markdown]
# # Exploring the relationship between aqueous solubility and Henry's law constants

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# for melting point predictions
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %matplotlib widget

# %%
# loading dataset
df = pd.read_csv('curated_aqsoldb.csv')

# %%
# filtering compounds that have both solubility and hcp values
matched = df[df['Hcp'].notnull()]

# %%
# taking the log of hcp values to make scale more accessible
matched['log Hcp'] = [math.log(x, 10) for x in matched['Hcp']]
# Out:
# C:\Users\Alastair\AppData\Local\Temp/ipykernel_28308/3497579970.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['log Hcp'] = [math.log(x, 10) for x in matched['Hcp']]

# %% [markdown]
# ### First plotting log S, log Hcp, and melting point against each other to see relationships

# %%
sns.scatterplot(data=matched, x='Solubility', y='log Hcp', s=3).set(xlabel='log S')
sns.despine()
plt.savefig('logs_loghcp.jpg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# filtering out compounds which don't have a mp value
mp_match = matched[matched['Melting Point'].notnull()]

# %%
plt.close()
sns.scatterplot(data=mp_match, x='Melting Point', y='Solubility', s=3).set(ylabel='log S')
sns.despine()
plt.savefig('logs_mp.jpg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()
sns.scatterplot(data=mp_match, x='Melting Point', y='log Hcp', s=3)
sns.despine()
plt.savefig('loghcp_mp.jpg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 3D scatter plot of solubility, hcp and mp values
fig = plt.figure(figsize=(8, 6), dpi=200)
ax = fig.add_subplot(projection='3d')

ax.scatter(mp_match['Solubility'], mp_match['Melting Point'], mp_match['log Hcp'], s=2)

ax.set_xlabel('log S')
ax.set_ylabel('Melting Point')
ax.set_zlabel('log Hcp')

plt.savefig('s_hcp_mp_scatter.jpg', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# 3D scatter plot of solubility, hcp and mp values
fig = plt.figure(figsize=(8, 6), dpi=200)
ax = fig.add_subplot(projection='3d')

ax.scatter(mp_match['Solubility'], mp_match['Melting Point'], mp_match['log Hcp'], s=2)

ax.set_xlabel('log S')
ax.set_ylabel('Melting Point')
ax.set_zlabel('log Hcp')

def rotate(angle):
    ax.view_init(azim=angle, elev=0)

# making an animation to save as gif
rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 362, 2), interval=100)
rot_animation.save('rotation.gif', dpi=300)

plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plotting plane of best fit

# %%
from skspatial.objects import Plane
from skspatial.objects import Points
from skspatial.plotting import plot_3d

from sklearn.preprocessing import PowerTransformer

# %%
# scaling melting points so is more comparable to log s and log hcp
pt = PowerTransformer(method='yeo-johnson', standardize=True)
mp_match['mpTransformed'] = pt.fit_transform(mp_match['Melting Point'].values.reshape(-1,1))
# Out:
# C:\Users\Alastair\AppData\Local\Temp/ipykernel_28308/4019934556.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mp_match['mpTransformed'] = pt.fit_transform(mp_match['Melting Point'].values.reshape(-1,1))

# %%
points = mp_match[['Solubility', 'mpTransformed', 'log Hcp']]

# %%
# converting relevant dataframe columns in numpy arrays which can be used as coordinates
points = points.to_numpy()

# %%
points
# Out:
# array([[-3.1231503 , -1.21488201, -2.50863831],
#        [-2.46603079,  0.61403469,  3.95424251],
#        [-3.41151388, -0.85332397, -3.537602  ],
#        ...,
#        [-2.73      ,  1.47772014,  7.50514998],
#        [-2.19      ,  0.24724936,  0.47712125],
#        [-4.78      ,  1.16901645,  4.56820172]])

# %%
# converting coordinates into skspatial Points object
points = Points(points)

# %%
# finding plane of best fit =
plane = Plane.best_fit(points)

# %%
fig = plt.figure(figsize=(8, 6), dpi=200)
ax = fig.add_subplot(projection='3d')

# plotting plane of best fit along with scatter points
points.plot_3d(ax, s=2)
plane.plot_3d(ax, lims_x=(-8, 5), lims_y=(-3, 3), alpha=0.2)

ax.set_xlabel('log S')
ax.set_ylabel('Melting Point (scaled)')
ax.set_zlabel('log Hcp')

# create function that rotates graph
def rotate(angle):
    ax.view_init(azim=angle, elev=0)

# making an animation of rotating graph to save as gif
rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 362, 2), interval=100)
rot_animation.save('rotation_with_plane.gif', dpi=300)

plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# cartesian coordiates of plane
plane.cartesian()
# Out:
# (-0.19526469583217496,
#  -0.9623754218329871,
#  0.18895831819040915,
#  -0.6933842186410031)

# %% [markdown]
# ### removing outliers to get better plane of best fit

# %% [markdown]
# taking outliers to be:
# - Q1 - 1.5 * IQR
# - Q3 + 1.5 * IQR

# %% [markdown]
# #### solubility outliers

# %%
# first finding log s outlier boundaries
q3, q1 = np.percentile(mp_match['Solubility'], [75, 25])

lower_outliers = q1 - 1.5 * (q3 - q1)
upper_outliers = q3 + 1.5 * (q3 - q1)

# %%
# removing outliers
mp_match = mp_match[mp_match['Solubility'] > lower_outliers]
mp_match = mp_match[mp_match['Solubility'] < upper_outliers]

# %%
mp_match
# Out:
#       level_0  index    ID                                               Name  \
# 5           5      5  A-10                                       vinyltoluene
# 16         16     16  A-24         2-(4-chloro-2-methylphenoxy)propanoic acid
# 18         18     18  A-26                1-chloro-3-(trifluoromethyl)benzene
# 27         27     27  A-36  (1S,5S)-6,6-dimethyl-2-methylidenebicyclo[3.1....
# 30         30     30  A-45                                      hydroxylamine
# ...       ...    ...   ...                                                ...
# 9965    10046   9965  I-63                                         papaverine
# 9967    10048   9967  I-66                                      phenobarbital
# 9974    10055   9974  I-79                                     sulfamethazine
# 9979    10060   9979  I-86                                             thymol
# 9981    10062   9981  I-94                                           warfarin
#
#                                                   InChI  \
# 5     InChI=1S/C9H10/c1-3-9-6-4-5-8(2)7-9/h3-7H,1H2,2H3
# 16    InChI=1S/C10H11ClO3/c1-6-5-8(11)3-4-9(6)14-7(2...
# 18    InChI=1S/C7H4ClF3/c8-6-3-1-2-5(4-6)7(9,10)11/h...
# 27    InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h8-9...
# 30                           InChI=1S/H3NO/c1-2/h2H,1H2
# ...                                                 ...
# 9965  InChI=1S/C20H21NO4/c1-22-17-6-5-13(10-18(17)23...
# 9967  InChI=1S/C12H12N2O3/c1-2-12(8-6-4-3-5-7-8)9(15...
# 9974  InChI=1S/C12H14N4O2S/c1-8-7-9(2)15-12(14-8)16-...
# 9979  InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)6-10(9)11/h4...
# 9981  InChI=1S/C19H16O4/c1-12(20)11-15(13-7-3-2-4-8-...
#
#                          InChIKey                                     SMILES  \
# 5     JZHGRUMIRATHIU-UHFFFAOYSA-N                             Cc1cccc(C=C)c1
# 16    WNTGYJSOUMFZEP-UHFFFAOYSA-N                   CC(Oc1ccc(Cl)cc1C)C(O)=O
# 18    YTCGOUNVIAWCMG-UHFFFAOYSA-N                       FC(F)(F)c1cccc(Cl)c1
# 27    WTARULDDTDQWMU-UHFFFAOYSA-N                        CC1(C)C2CCC(=C)C1C2
# 30    AVXURJPOCDRRFD-UHFFFAOYSA-N                                         NO
# ...                           ...                                        ...
# 9965  XQYZDYMELSJDRZ-UHFFFAOYSA-N  c1(nccc2cc(c(OC)cc12)OC)Cc1cc(c(cc1)OC)OC
# 9967  DDBREPKUVSBGFI-UHFFFAOYSA-N         C1(NC(C(c2ccccc2)(C(=O)N1)CC)=O)=O
# 9974  ASWVTGNCAZCNNR-UHFFFAOYSA-N      S(=O)(=O)(Nc1nc(C)cc(n1)C)c1ccc(N)cc1
# 9979  MGSRCZKZVOBKFT-UHFFFAOYSA-N                        c1(cc(ccc1C(C)C)C)O
# 9981  PJVWKTKQMONHTI-UHFFFAOYSA-N      CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#       Solubility        SD  Ocurrences  ...   TPSA   LabuteASA  BalabanJ  \
# 5      -3.123150  0.000000           1  ...   0.00   55.836626  3.070761
# 16     -2.466031  0.060621           4  ...  46.53   87.263739  2.817665
# 18     -3.411514  0.000000           1  ...   0.00   66.596218  3.059902
# 27     -4.292313  1.247787           3  ...   0.00   63.322465  2.231081
# 30     -0.763034  0.861298           7  ...  46.25   12.462472  1.000000
# ...          ...       ...         ...  ...    ...         ...       ...
# 9965   -3.870000  0.790000           2  ...  49.81  146.668701  2.039871
# 9967   -2.290000  0.095670           5  ...  75.27   98.199515  2.535973
# 9974   -2.730000  0.230750           2  ...  97.97  111.308206  2.330509
# 9979   -2.190000  0.019222           3  ...  20.23   67.685405  3.092720
# 9981   -4.780000  0.450506           3  ...  67.51  132.552025  2.258072
#
#          BertzCT                              Species           Hcp  \
# 5     211.033225            1-ethenyl-3-methylbenzene  3.100000e-03
# 16    349.220389                             mecoprop  9.000000e+03
# 18    254.107753  1-chloro-3-(trifluoromethyl)benzene  2.900000e-04
# 27    174.477332                       $\beta$-pinene  1.600000e-04
# 30      2.000000                        hydroxylamine  1.400000e+03
# ...          ...                                  ...           ...
# 9965  892.243703                           papaverine  1.300000e+07
# 9967  461.783925                        phenobarbital  5.800000e+08
# 9974  675.919365                       sulfamethazine  3.200000e+07
# 9979  251.049732    5-methyl-2-(1-methylethyl)-phenol  3.000000e+00
# 9981  909.550973                             warfarin  3.700000e+04
#
#              CID  Melting Point   log Hcp  mpTransformed
# 5         7529.0         -86.30 -2.508638      -1.214882
# 16        7153.0          94.50  3.954243       0.614035
# 18        7374.0         -56.00 -3.537602      -0.853324
# 27       14896.0         -61.25 -3.795880      -0.915520
# 30         787.0          33.00  3.146128       0.086132
# ...          ...            ...       ...            ...
# 9965      4680.0         147.50  7.113943       1.057225
# 9967      4763.0         174.00  8.763428       1.276322
# 9974      5327.0         198.50  7.505150       1.477720
# 9979      6989.0          51.50  0.477121       0.247249
# 9981  54678486.0         161.00  4.568202       1.169016
#
# [1802 rows x 34 columns]

# %% [markdown]
# #### HLC outliers

# %%
# finding hlc outlier boundaries
q3, q1 = np.percentile(mp_match['log Hcp'], [75, 25])

lower_outliers = q1 - 1.5 * (q3 - q1)
upper_outliers = q3 + 1.5 * (q3 - q1)

# %%
# removing outliers
mp_match = mp_match[mp_match['log Hcp'] > lower_outliers]
mp_match = mp_match[mp_match['log Hcp'] < upper_outliers]

# %%
mp_match
# Out:
#       level_0  index    ID                                               Name  \
# 5           5      5  A-10                                       vinyltoluene
# 16         16     16  A-24         2-(4-chloro-2-methylphenoxy)propanoic acid
# 18         18     18  A-26                1-chloro-3-(trifluoromethyl)benzene
# 27         27     27  A-36  (1S,5S)-6,6-dimethyl-2-methylidenebicyclo[3.1....
# 30         30     30  A-45                                      hydroxylamine
# ...       ...    ...   ...                                                ...
# 9965    10046   9965  I-63                                         papaverine
# 9967    10048   9967  I-66                                      phenobarbital
# 9974    10055   9974  I-79                                     sulfamethazine
# 9979    10060   9979  I-86                                             thymol
# 9981    10062   9981  I-94                                           warfarin
#
#                                                   InChI  \
# 5     InChI=1S/C9H10/c1-3-9-6-4-5-8(2)7-9/h3-7H,1H2,2H3
# 16    InChI=1S/C10H11ClO3/c1-6-5-8(11)3-4-9(6)14-7(2...
# 18    InChI=1S/C7H4ClF3/c8-6-3-1-2-5(4-6)7(9,10)11/h...
# 27    InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h8-9...
# 30                           InChI=1S/H3NO/c1-2/h2H,1H2
# ...                                                 ...
# 9965  InChI=1S/C20H21NO4/c1-22-17-6-5-13(10-18(17)23...
# 9967  InChI=1S/C12H12N2O3/c1-2-12(8-6-4-3-5-7-8)9(15...
# 9974  InChI=1S/C12H14N4O2S/c1-8-7-9(2)15-12(14-8)16-...
# 9979  InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)6-10(9)11/h4...
# 9981  InChI=1S/C19H16O4/c1-12(20)11-15(13-7-3-2-4-8-...
#
#                          InChIKey                                     SMILES  \
# 5     JZHGRUMIRATHIU-UHFFFAOYSA-N                             Cc1cccc(C=C)c1
# 16    WNTGYJSOUMFZEP-UHFFFAOYSA-N                   CC(Oc1ccc(Cl)cc1C)C(O)=O
# 18    YTCGOUNVIAWCMG-UHFFFAOYSA-N                       FC(F)(F)c1cccc(Cl)c1
# 27    WTARULDDTDQWMU-UHFFFAOYSA-N                        CC1(C)C2CCC(=C)C1C2
# 30    AVXURJPOCDRRFD-UHFFFAOYSA-N                                         NO
# ...                           ...                                        ...
# 9965  XQYZDYMELSJDRZ-UHFFFAOYSA-N  c1(nccc2cc(c(OC)cc12)OC)Cc1cc(c(cc1)OC)OC
# 9967  DDBREPKUVSBGFI-UHFFFAOYSA-N         C1(NC(C(c2ccccc2)(C(=O)N1)CC)=O)=O
# 9974  ASWVTGNCAZCNNR-UHFFFAOYSA-N      S(=O)(=O)(Nc1nc(C)cc(n1)C)c1ccc(N)cc1
# 9979  MGSRCZKZVOBKFT-UHFFFAOYSA-N                        c1(cc(ccc1C(C)C)C)O
# 9981  PJVWKTKQMONHTI-UHFFFAOYSA-N      CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#       Solubility        SD  Ocurrences  ...   TPSA   LabuteASA  BalabanJ  \
# 5      -3.123150  0.000000           1  ...   0.00   55.836626  3.070761
# 16     -2.466031  0.060621           4  ...  46.53   87.263739  2.817665
# 18     -3.411514  0.000000           1  ...   0.00   66.596218  3.059902
# 27     -4.292313  1.247787           3  ...   0.00   63.322465  2.231081
# 30     -0.763034  0.861298           7  ...  46.25   12.462472  1.000000
# ...          ...       ...         ...  ...    ...         ...       ...
# 9965   -3.870000  0.790000           2  ...  49.81  146.668701  2.039871
# 9967   -2.290000  0.095670           5  ...  75.27   98.199515  2.535973
# 9974   -2.730000  0.230750           2  ...  97.97  111.308206  2.330509
# 9979   -2.190000  0.019222           3  ...  20.23   67.685405  3.092720
# 9981   -4.780000  0.450506           3  ...  67.51  132.552025  2.258072
#
#          BertzCT                              Species           Hcp  \
# 5     211.033225            1-ethenyl-3-methylbenzene  3.100000e-03
# 16    349.220389                             mecoprop  9.000000e+03
# 18    254.107753  1-chloro-3-(trifluoromethyl)benzene  2.900000e-04
# 27    174.477332                       $\beta$-pinene  1.600000e-04
# 30      2.000000                        hydroxylamine  1.400000e+03
# ...          ...                                  ...           ...
# 9965  892.243703                           papaverine  1.300000e+07
# 9967  461.783925                        phenobarbital  5.800000e+08
# 9974  675.919365                       sulfamethazine  3.200000e+07
# 9979  251.049732    5-methyl-2-(1-methylethyl)-phenol  3.000000e+00
# 9981  909.550973                             warfarin  3.700000e+04
#
#              CID  Melting Point   log Hcp  mpTransformed
# 5         7529.0         -86.30 -2.508638      -1.214882
# 16        7153.0          94.50  3.954243       0.614035
# 18        7374.0         -56.00 -3.537602      -0.853324
# 27       14896.0         -61.25 -3.795880      -0.915520
# 30         787.0          33.00  3.146128       0.086132
# ...          ...            ...       ...            ...
# 9965      4680.0         147.50  7.113943       1.057225
# 9967      4763.0         174.00  8.763428       1.276322
# 9974      5327.0         198.50  7.505150       1.477720
# 9979      6989.0          51.50  0.477121       0.247249
# 9981  54678486.0         161.00  4.568202       1.169016
#
# [1764 rows x 34 columns]

# %% [markdown]
# #### melting point outliers

# %%
# finding mp outlier boundaries
q3, q1 = np.percentile(mp_match['mpTransformed'], [75, 25])

lower_outliers = q1 - 1.5 * (q3 - q1)
upper_outliers = q3 + 1.5 * (q3 - q1)

# %%
# removing outliers
mp_match = mp_match[mp_match['mpTransformed'] > lower_outliers]
mp_match = mp_match[mp_match['mpTransformed'] < upper_outliers]

# %%
mp_match
# Out:
#       level_0  index    ID                                               Name  \
# 5           5      5  A-10                                       vinyltoluene
# 16         16     16  A-24         2-(4-chloro-2-methylphenoxy)propanoic acid
# 18         18     18  A-26                1-chloro-3-(trifluoromethyl)benzene
# 27         27     27  A-36  (1S,5S)-6,6-dimethyl-2-methylidenebicyclo[3.1....
# 30         30     30  A-45                                      hydroxylamine
# ...       ...    ...   ...                                                ...
# 9965    10046   9965  I-63                                         papaverine
# 9967    10048   9967  I-66                                      phenobarbital
# 9974    10055   9974  I-79                                     sulfamethazine
# 9979    10060   9979  I-86                                             thymol
# 9981    10062   9981  I-94                                           warfarin
#
#                                                   InChI  \
# 5     InChI=1S/C9H10/c1-3-9-6-4-5-8(2)7-9/h3-7H,1H2,2H3
# 16    InChI=1S/C10H11ClO3/c1-6-5-8(11)3-4-9(6)14-7(2...
# 18    InChI=1S/C7H4ClF3/c8-6-3-1-2-5(4-6)7(9,10)11/h...
# 27    InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h8-9...
# 30                           InChI=1S/H3NO/c1-2/h2H,1H2
# ...                                                 ...
# 9965  InChI=1S/C20H21NO4/c1-22-17-6-5-13(10-18(17)23...
# 9967  InChI=1S/C12H12N2O3/c1-2-12(8-6-4-3-5-7-8)9(15...
# 9974  InChI=1S/C12H14N4O2S/c1-8-7-9(2)15-12(14-8)16-...
# 9979  InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)6-10(9)11/h4...
# 9981  InChI=1S/C19H16O4/c1-12(20)11-15(13-7-3-2-4-8-...
#
#                          InChIKey                                     SMILES  \
# 5     JZHGRUMIRATHIU-UHFFFAOYSA-N                             Cc1cccc(C=C)c1
# 16    WNTGYJSOUMFZEP-UHFFFAOYSA-N                   CC(Oc1ccc(Cl)cc1C)C(O)=O
# 18    YTCGOUNVIAWCMG-UHFFFAOYSA-N                       FC(F)(F)c1cccc(Cl)c1
# 27    WTARULDDTDQWMU-UHFFFAOYSA-N                        CC1(C)C2CCC(=C)C1C2
# 30    AVXURJPOCDRRFD-UHFFFAOYSA-N                                         NO
# ...                           ...                                        ...
# 9965  XQYZDYMELSJDRZ-UHFFFAOYSA-N  c1(nccc2cc(c(OC)cc12)OC)Cc1cc(c(cc1)OC)OC
# 9967  DDBREPKUVSBGFI-UHFFFAOYSA-N         C1(NC(C(c2ccccc2)(C(=O)N1)CC)=O)=O
# 9974  ASWVTGNCAZCNNR-UHFFFAOYSA-N      S(=O)(=O)(Nc1nc(C)cc(n1)C)c1ccc(N)cc1
# 9979  MGSRCZKZVOBKFT-UHFFFAOYSA-N                        c1(cc(ccc1C(C)C)C)O
# 9981  PJVWKTKQMONHTI-UHFFFAOYSA-N      CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#       Solubility        SD  Ocurrences  ...   TPSA   LabuteASA  BalabanJ  \
# 5      -3.123150  0.000000           1  ...   0.00   55.836626  3.070761
# 16     -2.466031  0.060621           4  ...  46.53   87.263739  2.817665
# 18     -3.411514  0.000000           1  ...   0.00   66.596218  3.059902
# 27     -4.292313  1.247787           3  ...   0.00   63.322465  2.231081
# 30     -0.763034  0.861298           7  ...  46.25   12.462472  1.000000
# ...          ...       ...         ...  ...    ...         ...       ...
# 9965   -3.870000  0.790000           2  ...  49.81  146.668701  2.039871
# 9967   -2.290000  0.095670           5  ...  75.27   98.199515  2.535973
# 9974   -2.730000  0.230750           2  ...  97.97  111.308206  2.330509
# 9979   -2.190000  0.019222           3  ...  20.23   67.685405  3.092720
# 9981   -4.780000  0.450506           3  ...  67.51  132.552025  2.258072
#
#          BertzCT                              Species           Hcp  \
# 5     211.033225            1-ethenyl-3-methylbenzene  3.100000e-03
# 16    349.220389                             mecoprop  9.000000e+03
# 18    254.107753  1-chloro-3-(trifluoromethyl)benzene  2.900000e-04
# 27    174.477332                       $\beta$-pinene  1.600000e-04
# 30      2.000000                        hydroxylamine  1.400000e+03
# ...          ...                                  ...           ...
# 9965  892.243703                           papaverine  1.300000e+07
# 9967  461.783925                        phenobarbital  5.800000e+08
# 9974  675.919365                       sulfamethazine  3.200000e+07
# 9979  251.049732    5-methyl-2-(1-methylethyl)-phenol  3.000000e+00
# 9981  909.550973                             warfarin  3.700000e+04
#
#              CID  Melting Point   log Hcp  mpTransformed
# 5         7529.0         -86.30 -2.508638      -1.214882
# 16        7153.0          94.50  3.954243       0.614035
# 18        7374.0         -56.00 -3.537602      -0.853324
# 27       14896.0         -61.25 -3.795880      -0.915520
# 30         787.0          33.00  3.146128       0.086132
# ...          ...            ...       ...            ...
# 9965      4680.0         147.50  7.113943       1.057225
# 9967      4763.0         174.00  8.763428       1.276322
# 9974      5327.0         198.50  7.505150       1.477720
# 9979      6989.0          51.50  0.477121       0.247249
# 9981  54678486.0         161.00  4.568202       1.169016
#
# [1763 rows x 34 columns]

# %% [markdown]
# ### now finding new plane of best fit

# %%
points = mp_match[['Solubility', 'mpTransformed', 'log Hcp']]

# %%
# converting relevant dataframe columns in numpy arrays which can be used as coordinates
points = points.to_numpy()

# %%
points
# Out:
# array([[-3.1231503 , -1.21488201, -2.50863831],
#        [-2.46603079,  0.61403469,  3.95424251],
#        [-3.41151388, -0.85332397, -3.537602  ],
#        ...,
#        [-2.73      ,  1.47772014,  7.50514998],
#        [-2.19      ,  0.24724936,  0.47712125],
#        [-4.78      ,  1.16901645,  4.56820172]])

# %%
# converting coordinates into skspatial Points object
points = Points(points)

# %%
# finding plane of best fit =
plane = Plane.best_fit(points)

# %%
plt.close()

fig = plt.figure(figsize=(8, 6), dpi=200)
ax = fig.add_subplot(projection='3d')

# plotting plane of best fit along with scatter points
points.plot_3d(ax, s=2)
plane.plot_3d(ax, lims_x=(-8, 5), lims_y=(-3, 3), alpha=0.2)

ax.set_xlabel('log S')
ax.set_ylabel('Melting Point (scaled)')
ax.set_zlabel('log Hcp')

# create function that rotates graph
def rotate(angle):
    ax.view_init(azim=angle, elev=0)

# making an animation of rotating graph to save as gif
rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 362, 2), interval=100)
rot_animation.save('rotation_with_plane_no_outliers.gif', dpi=300)

plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# cartesian coordiates of plane
plane.cartesian()
# Out:
# (-0.19028294066267004,
#  -0.9573843648705846,
#  0.21727305491964247,
#  -0.6799188586434917)

# %% [markdown]
# ## Melting point predictions using experimental data

# %% [markdown]
# using the equation -0.7891949689500798 * log S - 0.01926324742776453 * MP + 0.6138405560749627 * log Hcp - 1.9103492564962359 = 0

# %% [markdown]
# rearranging to find the MP gives the following equation -> MP = 1/0.01926324742776453 * (-0.7891949689500798 * log S + 0.6138405560749627 * log Hcp - 1.9103492564962359)

# %%
mp_match['MeltingPointExpPredicted'] = mp_match.apply(lambda x: 1/0.9573843648705846 * (-0.19028294066267004 * x['Solubility'] + 0.21727305491964247 * x['log Hcp'] - 0.6799188586434917), axis=1)

# %%
mp_match['MeltingPointExpPredicted'] = pt.inverse_transform(mp_match['MeltingPointExpPredicted'].values.reshape(-1, 1))

# %%
plt.clf()
sns.scatterplot(data=mp_match, x='Melting Point', y='MeltingPointExpPredicted', s=3).set(title='Melting point prediction using experimental solubility and HLC', xlabel='experimental melting point / °C', ylabel='predicted melting point / °C')

# set axis limits to be the same
plt.xlim(-250, 400)
plt.ylim(-250, 400)

sns.despine()
plt.savefig('mp_prediction.jpg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(mean_squared_error(mp_match['Melting Point'], mp_match['MeltingPointExpPredicted'], squared=False))
# Out:
# 63.94025666059953

# %%
r2_score(mp_match['Melting Point'], mp_match['MeltingPointExpPredicted'])
# Out:
# 0.5986618859549364

# %% [markdown]
# ## Melting point predictions using random forest predicted data

# %% [markdown]
# using the equation -0.7891949689500798 * log S - 0.01926324742776453 * MP + 0.6138405560749627 * log Hcp - 1.9103492564962359 = 0

# %% [markdown]
# rearranging to find the MP gives the following equation -> MP = 1/0.01926324742776453 * (-0.7891949689500798 * log S + 0.6138405560749627 * log Hcp - 1.9103492564962359)

# %%
# importing rfr solubility predictions
sol_predictions = pd.read_csv('best_sol_predictions.csv')

# inserting predictions into mp_match dataframe using InChIKey as foreign key
mp_match = mp_match.join(sol_predictions.set_index('InChIKey'), on='InChIKey')

# importing rfr hcp predictions
hcp_predictions = pd.read_csv('best_hcp_predictions.csv')

# inserting predictions into mp_match dataframe using InChIKey as foreign key
mp_match = mp_match.join(hcp_predictions.set_index('InChIKey'), on='InChIKey')

# %%
mp_match
# Out:
#       level_0  index    ID                                               Name  \
# 5           5      5  A-10                                       vinyltoluene
# 16         16     16  A-24         2-(4-chloro-2-methylphenoxy)propanoic acid
# 18         18     18  A-26                1-chloro-3-(trifluoromethyl)benzene
# 27         27     27  A-36  (1S,5S)-6,6-dimethyl-2-methylidenebicyclo[3.1....
# 30         30     30  A-45                                      hydroxylamine
# ...       ...    ...   ...                                                ...
# 9965    10046   9965  I-63                                         papaverine
# 9967    10048   9967  I-66                                      phenobarbital
# 9974    10055   9974  I-79                                     sulfamethazine
# 9979    10060   9979  I-86                                             thymol
# 9981    10062   9981  I-94                                           warfarin
#
#                                                   InChI  \
# 5     InChI=1S/C9H10/c1-3-9-6-4-5-8(2)7-9/h3-7H,1H2,2H3
# 16    InChI=1S/C10H11ClO3/c1-6-5-8(11)3-4-9(6)14-7(2...
# 18    InChI=1S/C7H4ClF3/c8-6-3-1-2-5(4-6)7(9,10)11/h...
# 27    InChI=1S/C10H16/c1-7-4-5-8-6-9(7)10(8,2)3/h8-9...
# 30                           InChI=1S/H3NO/c1-2/h2H,1H2
# ...                                                 ...
# 9965  InChI=1S/C20H21NO4/c1-22-17-6-5-13(10-18(17)23...
# 9967  InChI=1S/C12H12N2O3/c1-2-12(8-6-4-3-5-7-8)9(15...
# 9974  InChI=1S/C12H14N4O2S/c1-8-7-9(2)15-12(14-8)16-...
# 9979  InChI=1S/C10H14O/c1-7(2)9-5-4-8(3)6-10(9)11/h4...
# 9981  InChI=1S/C19H16O4/c1-12(20)11-15(13-7-3-2-4-8-...
#
#                          InChIKey                                     SMILES  \
# 5     JZHGRUMIRATHIU-UHFFFAOYSA-N                             Cc1cccc(C=C)c1
# 16    WNTGYJSOUMFZEP-UHFFFAOYSA-N                   CC(Oc1ccc(Cl)cc1C)C(O)=O
# 18    YTCGOUNVIAWCMG-UHFFFAOYSA-N                       FC(F)(F)c1cccc(Cl)c1
# 27    WTARULDDTDQWMU-UHFFFAOYSA-N                        CC1(C)C2CCC(=C)C1C2
# 30    AVXURJPOCDRRFD-UHFFFAOYSA-N                                         NO
# ...                           ...                                        ...
# 9965  XQYZDYMELSJDRZ-UHFFFAOYSA-N  c1(nccc2cc(c(OC)cc12)OC)Cc1cc(c(cc1)OC)OC
# 9967  DDBREPKUVSBGFI-UHFFFAOYSA-N         C1(NC(C(c2ccccc2)(C(=O)N1)CC)=O)=O
# 9974  ASWVTGNCAZCNNR-UHFFFAOYSA-N      S(=O)(=O)(Nc1nc(C)cc(n1)C)c1ccc(N)cc1
# 9979  MGSRCZKZVOBKFT-UHFFFAOYSA-N                        c1(cc(ccc1C(C)C)C)O
# 9981  PJVWKTKQMONHTI-UHFFFAOYSA-N      CC(=O)CC(c1ccccc1)c1c(O)c2ccccc2oc1=O
#
#       Solubility        SD  Ocurrences  ...           Hcp         CID  \
# 5      -3.123150  0.000000           1  ...  3.100000e-03      7529.0
# 16     -2.466031  0.060621           4  ...  9.000000e+03      7153.0
# 18     -3.411514  0.000000           1  ...  2.900000e-04      7374.0
# 27     -4.292313  1.247787           3  ...  1.600000e-04     14896.0
# 30     -0.763034  0.861298           7  ...  1.400000e+03       787.0
# ...          ...       ...         ...  ...           ...         ...
# 9965   -3.870000  0.790000           2  ...  1.300000e+07      4680.0
# 9967   -2.290000  0.095670           5  ...  5.800000e+08      4763.0
# 9974   -2.730000  0.230750           2  ...  3.200000e+07      5327.0
# 9979   -2.190000  0.019222           3  ...  3.000000e+00      6989.0
# 9981   -4.780000  0.450506           3  ...  3.700000e+04  54678486.0
#
#       Melting Point   log Hcp  mpTransformed  MeltingPointExpPredicted  \
# 5            -86.30 -2.508638      -1.214882                -39.444261
# 16            94.50  3.954243       0.614035                102.011929
# 18           -56.00 -3.537602      -0.853324                -54.447564
# 27           -61.25 -3.795880      -0.915520                -44.553559
# 30            33.00  3.146128       0.086132                 40.922642
# ...             ...       ...            ...                       ...
# 9965         147.50  7.113943       1.057225                222.425637
# 9967         174.00  8.763428       1.276322                229.818483
# 9974         198.50  7.505150       1.477720                205.571406
# 9979          51.50  0.477121       0.247249                  4.947084
# 9981         161.00  4.568202       1.169016                174.031701
#
#       PredictedSolValues  ActualSolValues  PredictedHcpValues  ActualHcpValues
# 5              -3.135679        -3.123150           -2.563800        -2.508638
# 16             -2.456292        -2.466031            3.413916         3.954243
# 18             -3.539270        -3.411514           -3.431213        -3.537602
# 27             -4.099664        -4.292313           -3.677351        -3.795880
# 30             -0.282212        -0.763034            2.784182         3.146128
# ...                  ...              ...                 ...              ...
# 9965           -4.100265        -3.870000            6.103074         7.113943
# 9967           -2.256784        -2.290000            8.325818         8.763428
# 9974           -2.646681        -2.730000            7.615607         7.505150
# 9979           -2.158710        -2.190000            0.538426         0.477121
# 9981           -3.930148        -4.780000            5.258591         4.568202
#
# [1763 rows x 39 columns]

# %%
mp_match['MeltingPointRFRPredicted'] = mp_match.apply(lambda x: 1/0.9573843648705846 * (-0.19028294066267004 * x['PredictedSolValues'] + 0.21727305491964247 * x['PredictedHcpValues'] - 0.6799188586434917), axis=1)

# %%
mp_match['MeltingPointRFRPredicted'] = pt.inverse_transform(mp_match['MeltingPointRFRPredicted'].values.reshape(-1, 1))

# %%
plt.clf()
sns.scatterplot(data=mp_match, x='Melting Point', y='MeltingPointRFRPredicted', s=3).set(title='Melting point prediction using predicted solubility and HLC', xlabel='experimental melting point / °C', ylabel='predicted melting point / °C')

# set axis limits to be the same
plt.xlim(-250, 400)
plt.ylim(-250, 400)

sns.despine()

plt.savefig('mp_prediction_rfr.jpg', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(mean_squared_error(mp_match['Melting Point'], mp_match['MeltingPointRFRPredicted'], squared=False))
# Out:
# 62.46019941970978

# %%
r2_score(mp_match['Melting Point'], mp_match['MeltingPointRFRPredicted'])
# Out:
# 0.6170267961090692

# %%
# exporting dataframe 
mp_match.to_csv('sol_hcp_mp.csv', index=False)
