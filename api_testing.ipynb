# %% [markdown]
# # API Testing

# %%
import requests
import json

# %%
url = "https://detherm.cds.dechema.de/api/properties/cid/67-68-5"

# %%
payload={}

# %%
headers = {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJRCI6IlBTRFMgRGV2ZWxvcGVyIiwiSU5TVCI6IlBTRFMiLCJERVBUIjoiRGV2ZWxvcG1lbnQiLCJpYXQiOjE2MzA1MzM2MDAsImV4cCI6MTY0MDk5MTU5OX0.Wx0zjAIbhQqPLpERyFI9zOqDfo2bzriBS6n7SP-2-QM'}

# %%
response = requests.request("GET", url, headers=headers)

# %%
response.text
# Out:
# '{"results":[{"system":{"systemId":149,"name":"sulfinylbismethane","components":[{"dsi":37297,"cid":"67-68-5","name":"sulfinylbismethane","frml":"C2H6OS","links":{"cid":"https:\\/\\/detherm.cds.dechema.de\\/api\\/components\\/cid\\/67-68-5"}}]},"properties":[{"comPid":"ACF.-.-","name":"acentric factor","longName":"acentric factor Omega","links":{"datasets":"https:\\/\\/detherm.cds.dechema.de\\/api\\/datasets\\/cid\\/67-68-5\\/ACF.-.-"}},{"comPid":"CDK.imag.L","name":"imag.dielec.con.","longName":"complex permittivity, imaginary part","phase":"L","links":{"datasets":"https:\\/\\/detherm.cds.dechema.de\\/api\\/datasets\\/cid\\/67-68-5\\/CDK.imag.L"}},{"comPid":"CDK.real.L","name":"real dielec.con.","longName":"complex permittivity, real part","phase":"L","links":{"datasets":"https:\\/\\/detherm.cds.dechema.de\\/api\\/datasets\\/cid\\/67-68-5\\/CDK.real.L"}},{"comPid":"CMF.crit.-","name":"(p.V\\/R.T) critical","longName":"critical compressibility factor","links":{"datasets":"https:\\/\\
# ...

# %%
def detherm_get(payload):
    headers = {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJRCI6IlBTRFMgRGV2ZWxvcGVyIiwiSU5TVCI6IlBTRFMiLCJERVBUIjoiRGV2ZWxvcG1lbnQiLCJpYXQiOjE2MzA1MzM2MDAsImV4cCI6MTY0MDk5MTU5OX0.Wx0zjAIbhQqPLpERyFI9zOqDfo2bzriBS6n7SP-2-QM'}
    url = "https://detherm.cds.dechema.de/api/properties/cid/67-68-5"
    
    payload['format'] = 'json'
    
    response = requests.get(url, headers=headers, params=payload)
    return response

# %%
r = detherm_get({'method': 'chart.gettopartists'})

# %%
def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
jprint(r.json())
# Out:
# {
#     "results": [
#         {
#             "properties": [
#                 {
#                     "comPid": "ACF.-.-",
#                     "links": {
#                         "datasets": "https://detherm.cds.dechema.de/api/datasets/cid/67-68-5/ACF.-.-"
#                     },
#                     "longName": "acentric factor Omega",
#                     "name": "acentric factor"
#                 },
#                 {
#                     "comPid": "CDK.imag.L",
#                     "links": {
#                         "datasets": "https://detherm.cds.dechema.de/api/datasets/cid/67-68-5/CDK.imag.L"
#                     },
#                     "longName": "complex permittivity, imaginary part",
#                     "name": "imag.dielec.con.",
#                     "phase": "L"
#                 },
#                 {
#                     "comPid": "CDK.real.L",
#                     "links": {
# ...
